# %%
include("FundsAllocation.jl")
import .FundsAllocation

# %%
cd("/home/ubuntu/funds-allocation")
pwd()
# Out:
# "/home/ubuntu/funds-allocation"

# %%
df_expenses = FundsAllocation.read_expenses("data_optimization.xlsx")
# Out:
# 25840×29 DataFrame
#    Row │ CC: Level  CC: Overall  CC: Field/ HQ/ Global/ Reserve  CC: Region  C ⋯
#        │ Int8       String       String                          String      S ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │         6  UNHCR        FIELD                           AFR         E ⋯
#      2 │         6  UNHCR        FIELD                           AFR         E
#      3 │         6  UNHCR        FIELD                           AFR         E
#      4 │         6  UNHCR        FIELD                           AFR         E
#      5 │         6  UNHCR        FIELD                           AFR         E ⋯
#      6 │         6  UNHCR        FIELD                           AFR         E
#      7 │         6  UNHCR        FIELD                           AFR         E
#      8 │         6  UNHCR        FIELD                           AFR         E
# ...

# %%
FundsAllocation.write_excel("data.xlsx", df_expenses, df_expenses, df_expenses)
